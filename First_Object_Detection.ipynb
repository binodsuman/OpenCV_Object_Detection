# %%
from imageai.Detection import ObjectDetection

# %%
import os

# %%
execution_path = os.getcwd()

# %%
detector = ObjectDetection()

# %%
detector.setModelTypeAsRetinaNet()

# %%
detector.setModelPath(os.path.join(execution_path,"resnet50_coco_best_v2.0.1.h5"))
detector.loadModel()

# %%
#custom_object = detector.CustomObjects(person=True)

# %%
#detection = detector.detectCustomObjectsFromImage(input_image=os.path.join(execution_path,"kids.JPG"),output_image_path=os.path.join(execution_path,"kids_new.JPG"),custom_objects=custom_object,minimum_percentage_probability= 45 )
detection = detector.detectCustomObjectsFromImage(input_image=os.path.join(execution_path,"image.JPG"),output_image_path=os.path.join(execution_path,"image_detec.JPG"))
#detection = detector.detectCustomObjectsFromImage(input_image=os.path.join(execution_path,"kids.JPG"),output_image_path=os.path.join(execution_path,"kids_new3.JPG"), extract_detected_objects=True)

# %%
for eachObject in detection:
    print(eachObject["name"] +" : "+eachObject["percentage_probability"])
    print("-----------------------------")
# Out:
# cake : 60.0764989853
# -----------------------------
# person : 91.8738484383
# -----------------------------
# person : 79.5981526375
# -----------------------------
# person : 79.4506669044
# -----------------------------
# person : 94.7387039661
# -----------------------------
# person : 63.9592289925
# -----------------------------
# person : 73.5305786133
# -----------------------------
# person : 53.3704698086
# -----------------------------

# %%
from IPython.display import Image

# %%
Image("image_new.png")

# %%
Image("kids_new.JPG")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
